# %% [markdown]
# ### 1. Градиентный спуск
#
# В данном разделе предстоит минимизировать функцию $$ f(x, y) = x^2 + y^2 $$ при помощи метода градиентного спуска

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# Задание 1. Реализуйте функцию gradient_vector таким образом, чтобы она возвращала градиент заданной функции f(x, y)
#
# должен возвращаться numpy array, содержащий 2 numpy array (производные по x и y)

# %%
def gradient_vector(x: np.array, y: np.array) -> np.array:
    # Вычисляем частные производные функции по x и y
    df_dx = 2 * x
    df_dy = 2 * y
    return np.array([df_dx, df_dy])

# %% [markdown]
# Задание 2. Реализуйте обновление координат найденного экстремума методом градиентного спуска.

# %%
def gradient_descent(vector, lr=0.001, epsilon=0.001, stop_iteration=10000):
    """

    Args:
        vector (np.array): исходные занчения аргументво x, y
        lr (float, optional): learning rate. Коэффициент скорости обучения.
        epsilon (float, optional): Допустимая погрешность
        stop_iteration (int, optional): количество итераций

    Returns:
        np.array, содержащий координаты экстремума, номер итерации, градиенты x, y, значения отклонений от истинного значения
    """
    iteration = 1

    x_gradient = np.array([])
    y_gradient =  np.array([])
    loss =  np.array([])

    extremum = vector - lr * gradient_vector(*vector)

    x_gradient = np.append(x_gradient, extremum[0])
    y_gradient = np.append(y_gradient, extremum[1])

    while np.linalg.norm(np.subtract(extremum[0], extremum[1])) > epsilon:
        loss = np.append(loss, np.absolute(vector[0]-extremum[0]))
        vector = extremum

        extremum = vector - lr * gradient_vector(*vector)

        x_gradient = np.append(x_gradient, extremum[0])
        y_gradient = np.append(y_gradient, extremum[1])

        iteration = iteration + 1
        if iteration == stop_iteration:
            break

    return extremum, iteration, x_gradient, y_gradient, loss

# %%
def plot_contour(x_gradient, y_gradient, vector):
    """
    Визуализация поиска точки экстремума
    """
    figure, ax = plt.subplots(1, 1, figsize=(10, 5))
    sns.set_theme(style='whitegrid', palette='pastel')

    contour = plt.contour(X, Y, Z, cmap=cm.RdBu)
    plt.clabel(contour, fontsize=10)

    ax.text(x=vector[0]+0.05, y=vector[1]-0.25, s='start', c='r')
    plt.plot(vector[0], vector[1], 'ro')

    ax.text(x=x_gradient[-1]+0.05, y=y_gradient[-1]-0.25, s='finish', c='b')
    plt.plot(x_gradient, y_gradient, 'bo')

    plt.show()

# %%
def plot_loss(loss):
    figure, ax = plt.subplots(1, 1, figsize=(10, 5))
    sns.set_theme(style='whitegrid', palette='pastel')

    ax = sns.lineplot(data=loss)
    ax.set(xlabel='Iteration')
    ax.set(ylabel='Value')
    ax.set_title('Losses')

    plt.show()

# %% [markdown]
# Инициализация функции для поиска точки экстремума, генерация значений функции.

# %% [markdown]
# $$   f(x, y) = x^2 + y^2 $$

# %%
def f(x, y):
    return np.power(x, 2) + np.power(y, 2)

x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %% [markdown]
# 3. Воспользуйтесь полученной функцией

# %%
vector = np.array([1, 2])
extremum, iteration, gdx_gradient, gdy_gradient, loss = gradient_descent(vector) # примените функцию gradient_descent с вашими параметрами

# %% [markdown]
# Визуализация градиентного спуска

# %%
print('Function extremum reached at point: ({:.5f}, {:.5f}).'.format(extremum[0], extremum[1]))
print('Number of iterations: {}.'.format(iteration))

plot_contour(gdx_gradient, gdy_gradient, vector)
# Out:
# Function extremum reached at point: (0.00100, 0.00200).
# Number of iterations: 3451.

# %% [markdown]
# Визуализация функции потерь

# %%
plot_loss(loss)

# %% [markdown]
# ### 2. Реализация нейронной сети для решения задачи классификации

# %%
# !wget  -O 'WineQT.csv' -q 'https://www.dropbox.com/scl/fi/qsacgxfmrio4d8crvksad/WineQT.csv?rlkey=o8mb42t8mfru5o9llgu98cxn6&dl=0'

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn

from tqdm import tqdm

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('WineQT.csv')

# %% [markdown]
# **Колонки**
#
# - fixed acidity
# - volatile acidity
# - citric acid
# - residual sugar
# - chlorides
# - free sulfur dioxide
# - total sulfur dioxide
# - density
# - pH
# - sulphates
# - alcohol
# - **quality (Target)** : score between 0 and 10
# - Id

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %% [markdown]
# Разделение на обучающую и тестовую выборки

# %%
df_train, df_val = train_test_split(df, test_size=0.2, random_state=42)# Ваш код для разделения на обучающую и тестовую выборки с размером тестовой 0.2

X_train = df_train.drop(['quality', 'Id'], axis=1)
X_val = df_val.drop(['quality', 'Id'], axis=1)

y_train = df_train['quality']
y_val = df_val['quality']

# %% [markdown]
# Задание 4. Примените RabustScaler для стандартизации X_train, X_val

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %% [markdown]
# Преобразование значений к тензорам, для дальнейшей работы с pyTorch

# %%
X_train_ts = torch.FloatTensor(X_train)
X_val_ts = torch.FloatTensor(X_val)

y_train_ts = torch.LongTensor(y_train.values)
y_val_ts = torch.LongTensor(y_val.values)

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()

        self.fc1 = nn.Linear(X_train_ts.shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 11)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)
        x = self.relu(x)

        x = self.fc3(x)
        x = self.relu(x)

        output = self.fc4(x)
        return output

# %%
model = DNN()

loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# Задание 5. Заполните пропуски функции train_model
#
# 1) Инициализируйте оптимизатор ADAM.
#
# 2) Воспользуйтесь методом zero_grad
#
# 3) Вычислите градиенты функции потерь по параметрам модели, используя метод обратного распространения ошибки. backward
#
# 4) Обновите значения оптимизатора. step

# %%
def train_model(model, lr=1e-3, n_epoch=500):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # Ваш код для инициализации оптимизатора

    train_losses = []
    val_losses = []

    train_scores = []
    val_scores = []

    for epoch in range(1, n_epoch+1):
        model.train()
        out = model(X_train_ts)
        loss = loss_fn(out, y_train_ts)

        optimizer.zero_grad() # Обнуление градиентов
        loss.backward()  # Вычисление градиентов функции
        optimizer.step()  # Обновление значений оптимизатора

        acc = (torch.argmax(out, dim=1) == y_train_ts).float().mean().item()

        model.eval()
        with torch.no_grad():
            out_val = model(X_val_ts)
            loss_val = loss_fn(out_val, y_val_ts)
            acc_val = (torch.argmax(out_val, dim=1) == y_val_ts).float().mean().item()

            train_losses.append(loss.item())
            val_losses.append(loss_val.item())

            train_scores.append(acc)
            val_scores.append(acc_val)

        if epoch % 20 == 0:
            print('Epoch : {:3d} / {}, Loss : {:.4f}, Accuracy : {:.2f} %, Val Loss : {:.4f}, Val Accuracy : {:.2f} %'.format(
                epoch, n_epoch, loss.item(), acc*100, loss_val.item(), acc_val*100))

    plt.plot(train_scores)
    plt.plot(val_scores)
    return train_losses, val_losses, train_losses, val_scores

# %%
train_model(model, n_epoch=750);
# Out:
# Epoch :  20 / 750, Loss : 1.8094, Accuracy : 50.77 %, Val Loss : 1.7627, Val Accuracy : 48.47 %
# Epoch :  40 / 750, Loss : 1.2055, Accuracy : 57.11 %, Val Loss : 1.1126, Val Accuracy : 56.33 %
# Epoch :  60 / 750, Loss : 1.0531, Accuracy : 58.42 %, Val Loss : 0.9634, Val Accuracy : 60.26 %
# Epoch :  80 / 750, Loss : 0.9862, Accuracy : 61.38 %, Val Loss : 0.9154, Val Accuracy : 62.45 %
# Epoch : 100 / 750, Loss : 0.9401, Accuracy : 62.25 %, Val Loss : 0.8919, Val Accuracy : 63.76 %
# Epoch : 120 / 750, Loss : 0.8999, Accuracy : 63.68 %, Val Loss : 0.8824, Val Accuracy : 62.45 %
# Epoch : 140 / 750, Loss : 0.8664, Accuracy : 65.10 %, Val Loss : 0.8806, Val Accuracy : 61.57 %
# Epoch : 160 / 750, Loss : 0.8364, Accuracy : 66.85 %, Val Loss : 0.8849, Val Accuracy : 61.14 %
# Epoch : 180 / 750, Loss : 0.8072, Accuracy : 68.38 %, Val Loss : 0.8907, Val Accuracy : 61.57 %
# Epoch : 200 / 750, Loss : 0.7777, Accuracy : 68.71 %, Val Loss : 0.8978, Val Accuracy : 61.57 %
# Epoch : 220 / 750, Loss : 0.7453, Accuracy : 70.35 %, Val Loss : 0.9073, Val Accuracy : 61.57 %
# Epoch : 240 / 750, Loss : 0.7096, Accuracy : 71.99 %, Val Loss : 0.9206, Val Accuracy : 61.57 %
# Epoch : 260 / 750, Loss : 0.6691, Accuracy : 74.07 %, Val Loss : 0.9448, Val Accuracy : 63.32 %
# Epoch : 280 / 750, Loss : 0.6210, Accuracy : 76.81 %, Val Loss : 0.9843, Val Accuracy : 63.32 %
# Epoch : 300 / 750, Loss : 0.5636, Accuracy : 78.99 %, Val Loss : 1.0344, Val Accuracy : 63.76 %
# Epoch : 320 / 750, Loss : 0.4982, Accuracy : 82.39 %, Val Loss : 1.0951, Val Accuracy : 64.19 %
# Epoch : 340 / 750, Loss : 0.4335, Accuracy : 86.65 %, Val Loss : 1.1660, Val Accuracy : 62.88 %
# Epoch : 360 / 750, Loss : 0.3694, Accuracy : 90.15 %, Val Loss : 1.2609, Val Accuracy : 62.88 %
# Epoch : 380 / 750, Loss : 0.3100, Accuracy : 92.45 %, Val Loss : 1.3705, Val Accuracy : 62.45 %
# Epoch : 400 / 750, Loss : 0.2589, Accuracy : 93.54 %, Val Loss : 1.4873, Val Accuracy : 62.45 %
# Epoch : 420 / 750, Loss : 0.2155, Accuracy : 94.97 %, Val Loss : 1.6476, Val Accuracy : 62.01 %
# Epoch : 440 / 750, Loss : 0.1797, Accuracy : 95.73 %, Val Loss : 1.8005, Val Accuracy : 61.14 %
# Epoch : 460 / 750, Loss : 0.1497, Accuracy : 96.83 %, Val Loss : 1.9455, Val Accuracy : 61.57 %
# Epoch : 480 / 750, Loss : 0.1246, Accuracy : 97.48 %, Val Loss : 2.1009, Val Accuracy : 61.14 %
# Epoch : 500 / 750, Loss : 0.1042, Accuracy : 98.03 %, Val Loss : 2.2645, Val Accuracy : 61.14 %
# Epoch : 520 / 750, Loss : 0.0872, Accuracy : 98.36 %, Val Loss : 2.4272, Val Accuracy : 61.57 %
# Epoch : 540 / 750, Loss : 0.0731, Accuracy : 98.91 %, Val Loss : 2.5882, Val Accuracy : 61.57 %
# Epoch : 560 / 750, Loss : 0.0616, Accuracy : 99.34 %, Val Loss : 2.7435, Val Accuracy : 61.57 %
# Epoch : 580 / 750, Loss : 0.0524, Accuracy : 99.45 %, Val Loss : 2.8881, Val Accuracy : 61.14 %
# Epoch : 600 / 750, Loss : 0.0449, Accuracy : 99.45 %, Val Loss : 3.0263, Val Accuracy : 61.14 %
# Epoch : 620 / 750, Loss : 0.0387, Accuracy : 99.56 %, Val Loss : 3.1564, Val Accuracy : 60.70 %
# Epoch : 640 / 750, Loss : 0.0337, Accuracy : 99.67 %, Val Loss : 3.2765, Val Accuracy : 60.70 %
# Epoch : 660 / 750, Loss : 0.0295, Accuracy : 99.67 %, Val Loss : 3.3939, Val Accuracy : 60.70 %
# Epoch : 680 / 750, Loss : 0.0259, Accuracy : 99.78 %, Val Loss : 3.5004, Val Accuracy : 60.70 %
# Epoch : 700 / 750, Loss : 0.0229, Accuracy : 99.78 %, Val Loss : 3.6028, Val Accuracy : 60.70 %
# Epoch : 720 / 750, Loss : 0.0203, Accuracy : 100.00 %, Val Loss : 3.7007, Val Accuracy : 60.26 %
# Epoch : 740 / 750, Loss : 0.0182, Accuracy : 100.00 %, Val Loss : 3.7910, Val Accuracy : 60.26 %

# %% [markdown]
# Можно наблюдать переобучение, так как при росте точности на обучающей выборке, на валидационной ее значение начало снижаться

# %% [markdown]
# Задание 6. Проверьте различные конфигурации (число слоев, их размер) модели DNN.
#
# Можете также опробовать различное число эпох и значения learning_rate при обучении.
#
# Требуется найти такую конфигурацию, при которой переобучения не будет

# %%
# Попробуем уменьшить learning_rate
model = DNN()
loss_fn = nn.CrossEntropyLoss()
train_model(model, lr=1e-4, n_epoch=750);
# Out:
# Epoch :  20 / 750, Loss : 2.4668, Accuracy : 0.66 %, Val Loss : 2.4689, Val Accuracy : 0.00 %
# Epoch :  40 / 750, Loss : 2.4324, Accuracy : 1.75 %, Val Loss : 2.4348, Val Accuracy : 0.44 %
# Epoch :  60 / 750, Loss : 2.3916, Accuracy : 3.06 %, Val Loss : 2.3938, Val Accuracy : 1.31 %
# Epoch :  80 / 750, Loss : 2.3369, Accuracy : 5.80 %, Val Loss : 2.3376, Val Accuracy : 4.37 %
# Epoch : 100 / 750, Loss : 2.2583, Accuracy : 20.68 %, Val Loss : 2.2562, Val Accuracy : 22.71 %
# Epoch : 120 / 750, Loss : 2.1543, Accuracy : 42.01 %, Val Loss : 2.1502, Val Accuracy : 41.48 %
# Epoch : 140 / 750, Loss : 2.0355, Accuracy : 45.08 %, Val Loss : 2.0299, Val Accuracy : 45.41 %
# Epoch : 160 / 750, Loss : 1.9091, Accuracy : 44.09 %, Val Loss : 1.9007, Val Accuracy : 44.10 %
# Epoch : 180 / 750, Loss : 1.7806, Accuracy : 45.30 %, Val Loss : 1.7661, Val Accuracy : 44.54 %
# Epoch : 200 / 750, Loss : 1.6568, Accuracy : 47.81 %, Val Loss : 1.6335, Val Accuracy : 45.85 %
# Epoch : 220 / 750, Loss : 1.5424, Accuracy : 52.95 %, Val Loss : 1.5070, Val Accuracy : 49.34 %
# Epoch : 240 / 750, Loss : 1.4434, Accuracy : 55.58 %, Val Loss : 1.3991, Val Accuracy : 51.97 %
# Epoch : 260 / 750, Loss : 1.3626, Accuracy : 56.56 %, Val Loss : 1.3144, Val Accuracy : 52.84 %
# Epoch : 280 / 750, Loss : 1.2977, Accuracy : 57.33 %, Val Loss : 1.2454, Val Accuracy : 55.02 %
# Epoch : 300 / 750, Loss : 1.2459, Accuracy : 57.22 %, Val Loss : 1.1906, Val Accuracy : 56.77 %
# Epoch : 320 / 750, Loss : 1.2043, Accuracy : 57.88 %, Val Loss : 1.1457, Val Accuracy : 57.21 %
# Epoch : 340 / 750, Loss : 1.1700, Accuracy : 58.21 %, Val Loss : 1.1082, Val Accuracy : 58.52 %
# Epoch : 360 / 750, Loss : 1.1414, Accuracy : 58.32 %, Val Loss : 1.0768, Val Accuracy : 58.95 %
# Epoch : 380 / 750, Loss : 1.1171, Accuracy : 58.86 %, Val Loss : 1.0501, Val Accuracy : 57.64 %
# Epoch : 400 / 750, Loss : 1.0965, Accuracy : 59.52 %, Val Loss : 1.0273, Val Accuracy : 58.52 %
# Epoch : 420 / 750, Loss : 1.0789, Accuracy : 59.96 %, Val Loss : 1.0078, Val Accuracy : 59.83 %
# Epoch : 440 / 750, Loss : 1.0638, Accuracy : 60.61 %, Val Loss : 0.9911, Val Accuracy : 61.57 %
# Epoch : 460 / 750, Loss : 1.0505, Accuracy : 60.39 %, Val Loss : 0.9767, Val Accuracy : 61.57 %
# Epoch : 480 / 750, Loss : 1.0387, Accuracy : 61.16 %, Val Loss : 0.9639, Val Accuracy : 62.01 %
# Epoch : 500 / 750, Loss : 1.0281, Accuracy : 61.05 %, Val Loss : 0.9530, Val Accuracy : 60.70 %
# Epoch : 520 / 750, Loss : 1.0183, Accuracy : 61.27 %, Val Loss : 0.9432, Val Accuracy : 61.57 %
# Epoch : 540 / 750, Loss : 1.0093, Accuracy : 61.38 %, Val Loss : 0.9350, Val Accuracy : 62.01 %
# Epoch : 560 / 750, Loss : 1.0009, Accuracy : 62.47 %, Val Loss : 0.9277, Val Accuracy : 62.45 %
# Epoch : 580 / 750, Loss : 0.9930, Accuracy : 62.36 %, Val Loss : 0.9215, Val Accuracy : 62.45 %
# Epoch : 600 / 750, Loss : 0.9856, Accuracy : 62.58 %, Val Loss : 0.9163, Val Accuracy : 62.88 %
# Epoch : 620 / 750, Loss : 0.9784, Accuracy : 62.80 %, Val Loss : 0.9116, Val Accuracy : 62.45 %
# Epoch : 640 / 750, Loss : 0.9714, Accuracy : 62.36 %, Val Loss : 0.9076, Val Accuracy : 62.45 %
# Epoch : 660 / 750, Loss : 0.9646, Accuracy : 62.47 %, Val Loss : 0.9036, Val Accuracy : 62.45 %
# Epoch : 680 / 750, Loss : 0.9579, Accuracy : 62.91 %, Val Loss : 0.9004, Val Accuracy : 62.88 %
# Epoch : 700 / 750, Loss : 0.9514, Accuracy : 63.24 %, Val Loss : 0.8975, Val Accuracy : 62.45 %
# Epoch : 720 / 750, Loss : 0.9449, Accuracy : 63.79 %, Val Loss : 0.8950, Val Accuracy : 62.45 %
# Epoch : 740 / 750, Loss : 0.9385, Accuracy : 63.89 %, Val Loss : 0.8932, Val Accuracy : 62.01 %

# %% [markdown]
# Видно, что переобучения в этом случае нет, попробуем изменить количество слоев и число эпох.

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()

        self.fc1 = nn.Linear(X_train_ts.shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 16)  # Добавлен новый слой
        self.fc5 = nn.Linear(16, 11)   # Новый выходной слой
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)
        x = self.relu(x)

        x = self.fc3(x)
        x = self.relu(x)

        x = self.fc4(x)  # Применяем новый слой
        x = self.relu(x)

        output = self.fc5(x)
        return output

# %%
model = DNN()
loss_fn = nn.CrossEntropyLoss()
train_model(model, lr=1e-4, n_epoch=1000);
# Out:
# Epoch :  20 / 1000, Loss : 2.3737, Accuracy : 0.00 %, Val Loss : 2.3710, Val Accuracy : 0.00 %
# Epoch :  40 / 1000, Loss : 2.3471, Accuracy : 1.31 %, Val Loss : 2.3427, Val Accuracy : 1.31 %
# Epoch :  60 / 1000, Loss : 2.3131, Accuracy : 19.15 %, Val Loss : 2.3081, Val Accuracy : 23.58 %
# Epoch :  80 / 1000, Loss : 2.2684, Accuracy : 40.15 %, Val Loss : 2.2641, Val Accuracy : 40.61 %
# Epoch : 100 / 1000, Loss : 2.2097, Accuracy : 42.34 %, Val Loss : 2.2069, Val Accuracy : 41.92 %
# Epoch : 120 / 1000, Loss : 2.1338, Accuracy : 42.34 %, Val Loss : 2.1334, Val Accuracy : 41.92 %
# Epoch : 140 / 1000, Loss : 2.0411, Accuracy : 42.34 %, Val Loss : 2.0434, Val Accuracy : 41.92 %
# Epoch : 160 / 1000, Loss : 1.9352, Accuracy : 42.34 %, Val Loss : 1.9383, Val Accuracy : 41.92 %
# Epoch : 180 / 1000, Loss : 1.8206, Accuracy : 42.34 %, Val Loss : 1.8170, Val Accuracy : 41.92 %
# Epoch : 200 / 1000, Loss : 1.7019, Accuracy : 42.34 %, Val Loss : 1.6846, Val Accuracy : 41.92 %
# Epoch : 220 / 1000, Loss : 1.5862, Accuracy : 42.34 %, Val Loss : 1.5514, Val Accuracy : 41.92 %
# Epoch : 240 / 1000, Loss : 1.4814, Accuracy : 45.73 %, Val Loss : 1.4294, Val Accuracy : 44.54 %
# Epoch : 260 / 1000, Loss : 1.3938, Accuracy : 51.20 %, Val Loss : 1.3272, Val Accuracy : 49.78 %
# Epoch : 280 / 1000, Loss : 1.3242, Accuracy : 52.08 %, Val Loss : 1.2473, Val Accuracy : 53.71 %
# Epoch : 300 / 1000, Loss : 1.2694, Accuracy : 55.03 %, Val Loss : 1.1865, Val Accuracy : 53.71 %
# Epoch : 320 / 1000, Loss : 1.2254, Accuracy : 56.35 %, Val Loss : 1.1398, Val Accuracy : 56.33 %
# Epoch : 340 / 1000, Loss : 1.1894, Accuracy : 56.56 %, Val Loss : 1.1034, Val Accuracy : 58.08 %
# Epoch : 360 / 1000, Loss : 1.1596, Accuracy : 57.55 %, Val Loss : 1.0747, Val Accuracy : 58.95 %
# Epoch : 380 / 1000, Loss : 1.1347, Accuracy : 57.66 %, Val Loss : 1.0512, Val Accuracy : 58.95 %
# Epoch : 400 / 1000, Loss : 1.1143, Accuracy : 58.21 %, Val Loss : 1.0322, Val Accuracy : 58.52 %
# Epoch : 420 / 1000, Loss : 1.0975, Accuracy : 58.32 %, Val Loss : 1.0162, Val Accuracy : 58.95 %
# Epoch : 440 / 1000, Loss : 1.0832, Accuracy : 58.53 %, Val Loss : 1.0031, Val Accuracy : 59.39 %
# Epoch : 460 / 1000, Loss : 1.0707, Accuracy : 59.30 %, Val Loss : 0.9917, Val Accuracy : 60.70 %
# Epoch : 480 / 1000, Loss : 1.0593, Accuracy : 60.72 %, Val Loss : 0.9815, Val Accuracy : 61.14 %
# Epoch : 500 / 1000, Loss : 1.0491, Accuracy : 61.38 %, Val Loss : 0.9727, Val Accuracy : 61.57 %
# Epoch : 520 / 1000, Loss : 1.0398, Accuracy : 61.71 %, Val Loss : 0.9648, Val Accuracy : 61.57 %
# Epoch : 540 / 1000, Loss : 1.0311, Accuracy : 62.14 %, Val Loss : 0.9581, Val Accuracy : 62.45 %
# Epoch : 560 / 1000, Loss : 1.0229, Accuracy : 62.47 %, Val Loss : 0.9520, Val Accuracy : 62.45 %
# Epoch : 580 / 1000, Loss : 1.0150, Accuracy : 62.69 %, Val Loss : 0.9462, Val Accuracy : 62.88 %
# Epoch : 600 / 1000, Loss : 1.0075, Accuracy : 62.58 %, Val Loss : 0.9409, Val Accuracy : 62.45 %
# Epoch : 620 / 1000, Loss : 1.0003, Accuracy : 62.58 %, Val Loss : 0.9361, Val Accuracy : 62.45 %
# Epoch : 640 / 1000, Loss : 0.9932, Accuracy : 63.24 %, Val Loss : 0.9316, Val Accuracy : 62.01 %
# Epoch : 660 / 1000, Loss : 0.9863, Accuracy : 63.24 %, Val Loss : 0.9275, Val Accuracy : 62.01 %
# Epoch : 680 / 1000, Loss : 0.9796, Accuracy : 63.24 %, Val Loss : 0.9238, Val Accuracy : 62.01 %
# Epoch : 700 / 1000, Loss : 0.9730, Accuracy : 62.91 %, Val Loss : 0.9205, Val Accuracy : 62.45 %
# Epoch : 720 / 1000, Loss : 0.9665, Accuracy : 62.80 %, Val Loss : 0.9178, Val Accuracy : 61.57 %
# Epoch : 740 / 1000, Loss : 0.9602, Accuracy : 62.91 %, Val Loss : 0.9155, Val Accuracy : 60.70 %
# Epoch : 760 / 1000, Loss : 0.9539, Accuracy : 62.80 %, Val Loss : 0.9135, Val Accuracy : 61.14 %
# Epoch : 780 / 1000, Loss : 0.9477, Accuracy : 63.13 %, Val Loss : 0.9115, Val Accuracy : 62.01 %
# Epoch : 800 / 1000, Loss : 0.9416, Accuracy : 63.35 %, Val Loss : 0.9097, Val Accuracy : 62.01 %
# Epoch : 820 / 1000, Loss : 0.9356, Accuracy : 63.57 %, Val Loss : 0.9078, Val Accuracy : 62.01 %
# Epoch : 840 / 1000, Loss : 0.9297, Accuracy : 63.02 %, Val Loss : 0.9061, Val Accuracy : 62.01 %
# Epoch : 860 / 1000, Loss : 0.9239, Accuracy : 63.35 %, Val Loss : 0.9043, Val Accuracy : 61.57 %
# Epoch : 880 / 1000, Loss : 0.9182, Accuracy : 63.46 %, Val Loss : 0.9027, Val Accuracy : 62.45 %
# Epoch : 900 / 1000, Loss : 0.9125, Accuracy : 63.57 %, Val Loss : 0.9016, Val Accuracy : 62.88 %
# Epoch : 920 / 1000, Loss : 0.9069, Accuracy : 63.68 %, Val Loss : 0.9007, Val Accuracy : 62.88 %
# Epoch : 940 / 1000, Loss : 0.9014, Accuracy : 64.00 %, Val Loss : 0.8998, Val Accuracy : 63.32 %
# Epoch : 960 / 1000, Loss : 0.8960, Accuracy : 64.22 %, Val Loss : 0.8994, Val Accuracy : 63.32 %
# Epoch : 980 / 1000, Loss : 0.8906, Accuracy : 64.44 %, Val Loss : 0.8992, Val Accuracy : 62.88 %
# Epoch : 1000 / 1000, Loss : 0.8852, Accuracy : 65.10 %, Val Loss : 0.8985, Val Accuracy : 62.88 %

# %% [markdown]
# Явного переобучения не наблюдается с добавлением слоев и увеличением числа эпох, однако наибольшее влияение сыграло уменьшение learning rate.
